# %%
# %pip install scikit-learn
# %pip install matplotlib

import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
# ...
#   Using cached kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
# ...
#   Using cached contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# ...
#      |████████████████████████████████| 111 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.8 MB 2.9 MB/s eta 0:00:01
# ...

# %%
N = 100

X = np.random.uniform(0, 5, size=N)

# y = 2*x + 1
y =  2 * X + 1 + np.random.normal(0, 1, size=N)
# for i in range(len(X)): 
#   y[i] = 2* X[i] + 1 + noise[i]

plt.scatter(X,y)

ls = np.linspace(0,5,100)
plt.plot(ls, ls * 2 + 1)
plt.show()

# %%
model = LinearRegression()  #https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

model.fit(X.reshape(-1,1), y) # [1,2,3] -> [[1], [2], [3]]
y_pred = model.predict(X.reshape(-1,1))

plt.scatter(X, y)
ls = np.linspace(0, 5, 100)
ls = ls.reshape(-1,1)

ls_pred = model.predict(ls)
plt.plot(ls, ls_pred, label='prediction')

#ls = np.linspace(0,5,100)
plt.plot(ls, ls * 2 + 1, label='real')
plt.legend()
plt.show()

# %%
N = 10

X = np.random.uniform(0, 5, size=N)
X = np.linspace(0,5,N)

y =  2 * X + 1 #+ np.random.normal(0, 1, size=N)

y[N // 2] += 5

plt.scatter(X,y)

model = LinearRegression()

model.fit(X.reshape(-1,1),y)

ls = np.linspace(0, 5, 100)
ls = ls.reshape(-1,1)

ls_pred = model.predict(ls)
plt.plot(ls, ls_pred, label='prediction')

# %%
N = 10
X = np.random.uniform(0, 5, size=N)
X = np.linspace(-5,5,N)

y =  X**2 + 1 #+ np.random.normal(0, 1, size=N)


plt.scatter(X,y)

model = LinearRegression()

model.fit(X.reshape(-1,1),y)
y_pred = model.predict(X.reshape(-1,1))

print(f'MSE is {mean_squared_error(y, y_pred)}')
print(f'r2_score {r2_score(y, y_pred)}')

ls = np.linspace(-5, 5, 100)
ls = ls.reshape(-1,1)

ls_pred = model.predict(ls)
plt.plot(ls, ls_pred, label='prediction')
plt.show()
# Out:
# MSE is 57.805549286010454
# r2_score 0.0

# %%
N = 10

X = np.random.uniform(0, 5, size=N)
X = np.linspace(0,5,N)

y =  2 * X + 1 + np.random.normal(0, 1, size=N)



plt.scatter(X,y)

model = LinearRegression()

model.fit(X.reshape(-1,1),y)

y_pred = model.predict(X.reshape(-1,1))

print(f'MSE is {mean_squared_error(y, y_pred)}')
print(f'r2_score {r2_score(y, y_pred)}')
print(f'w_1: {model.coef_} w_0: {model.intercept_}')

ls = np.linspace(0, 5, 100)
ls = ls.reshape(-1,1)

ls_pred = model.predict(ls)
plt.plot(ls, ls_pred, label='prediction')

# h = w1 * x
# a inače je oblika h = w0 + w1 * x
# Out:
# MSE is 0.5359834898618969
# r2_score 0.9582550590477379
# w_1: [2.19816289] w_0: 1.016076989225989
